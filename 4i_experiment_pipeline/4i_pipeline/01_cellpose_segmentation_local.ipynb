# %% [markdown]
# ## About this notebook

# %% [markdown]
# This notebook segments files selected for calculating alignment in each round.
#
# Input:
# - pathway to a directory containing selected files for the segmentation (im_to_segment)
# - list of wells to process
#
# Output:
# - segmented masks of selected channels

# %% [markdown]
# ## Fill in info about the experiment to process

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..', 'src'))
from project_config import load_config

config    = load_config()
base_dir  = config['base_dir']
well_list = config['well_list']

# Sub-folder paths
path_data = os.path.join(base_dir, 'output_images')
path_save = os.path.join(base_dir, 'segmented')

# Segmentation settings
selected_diameter = 30

# To process one well at a time, use SingleWellSelector:
# from well_plate_selector import SingleWellSelector
# selector = SingleWellSelector(); selector.show()
# Then in the masking cell: well = selector.well

# %% [markdown]
# ## Prepare for segmentation

# %%
import os
from tifffile import imread
import pickle
from skimage.io import imsave
import tensorflow as tf
import cellpose
from cellpose import models
from cellpose import utils

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
#Is cellpose using the GPU, reports True or False
cellpose.core.use_gpu(gpu_number=0, use_torch=True)
# Out:
# True

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Tue_Mar__8_18:36:24_Pacific_Standard_Time_2022
# Cuda compilation tools, release 11.6, V11.6.124
# Build cuda_11.6.r11.6/compiler.31057947_0
# Thu Mar  5 12:58:39 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 573.44                 Driver Version: 573.44         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A4000             WDDM  |   00000000:55:00.0  On |                  Off |
# | 41%   36C    P8             16W /  140W |    1001MiB /  16376MiB |     10%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2748    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A            3188    C+G   ....0.3800.82\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            7420      C   ...nvs\GPU_Segment_4i\python.exe      N/A      |
# |    0   N/A  N/A            8976    C+G   ....0.3800.82\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            9672    C+G   ...8wekyb3d8bbwe\M365Copilot.exe      N/A      |
# |    0   N/A  N/A           10652    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           11900    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           13724    C+G   ...s\Win64\EpicGamesLauncher.exe      N/A      |
# |    0   N/A  N/A           13812    C+G   ...crosoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           14468    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           14484    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           15512    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           15660    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           16084    C+G   ...l\slack\app-4.48.95\slack.exe      N/A      |
# |    0   N/A  N/A           17468    C+G   ....0.3800.82\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           17576    C+G   ...aries\Win64\EpicWebHelper.exe      N/A      |
# |    0   N/A  N/A           19396    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           19812    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
try:
    #os.mkdir(save_dir)
    os.mkdir(path_save)
    print('Directory for saving created.')
except:
    print('Directory not created.')
# Out:
# Directory for saving created.

# %%
# load cellpose model
model = models.Cellpose(gpu=True, model_type='cyto')
#model = models.Cellpose(gpu=False, model_type='cyto')

# %% [markdown]
# ## Process selected wells

# %%
# loop for segmentation 

for myWell in well_list:
    
    file_list = os.listdir(os.path.join(path_data,myWell))
    
    try:
        os.mkdir(os.path.join(path_save,myWell))
        print(f'Directory for saving {myWell} labels created.')
    except:
        pass

    for file_name in file_list: 

        # specify pathway to the image
        im_path = os.path.join(path_data,myWell,file_name)

        # get an image
        im = imread(im_path)

        # segment the right plane
        labels, _, _, _ = model.eval(im, diameter=selected_diameter, channels=[0,0])

        # save segmentation
        path_save_temp = os.path.join(path_save,myWell,file_name.replace('im2segment','labels'))
        imsave(path_save_temp,labels)
# Out:
# Directory for saving B02 labels created.
# Directory for saving B03 labels created.
# Directory for saving B04 labels created.
# Directory for saving B05 labels created.
# Directory for saving B06 labels created.
# Directory for saving B07 labels created.
# Directory for saving C02 labels created.
# Directory for saving C03 labels created.
# Directory for saving C04 labels created.
# Directory for saving C05 labels created.
# Directory for saving C06 labels created.
# Directory for saving C07 labels created.
# Directory for saving D02 labels created.
# Directory for saving D03 labels created.
# Directory for saving D04 labels created.
# Directory for saving D05 labels created.
# Directory for saving D06 labels created.
# Directory for saving D07 labels created.
# Directory for saving E02 labels created.
# Directory for saving E03 labels created.
# Directory for saving E04 labels created.
# Directory for saving E05 labels created.
# Directory for saving E06 labels created.
# Directory for saving E07 labels created.
# Directory for saving F02 labels created.
# Directory for saving F03 labels created.
# more than 65535 masks in image, masks returned as np.uint32
# c:\Users\Purvis_Jane\.conda\envs\GPU_Segment_4i\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Z:\Clara\20260304_Exp 1.2\segmented\F03\labels_F03_round_000.tif is a low contrast image
# more than 65535 masks in image, masks returned as np.uint32
# c:\Users\Purvis_Jane\.conda\envs\GPU_Segment_4i\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Z:\Clara\20260304_Exp 1.2\segmented\F03\labels_F03_round_001.tif is a low contrast image
# more than 65535 masks in image, masks returned as np.uint32
# c:\Users\Purvis_Jane\.conda\envs\GPU_Segment_4i\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Z:\Clara\20260304_Exp 1.2\segmented\F03\labels_F03_round_002.tif is a low contrast image
# more than 65535 masks in image, masks returned as np.uint32
# c:\Users\Purvis_Jane\.conda\envs\GPU_Segment_4i\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Z:\Clara\20260304_Exp 1.2\segmented\F03\labels_F03_round_003.tif is a low contrast image
# more than 65535 masks in image, masks returned as np.uint32
# c:\Users\Purvis_Jane\.conda\envs\GPU_Segment_4i\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Z:\Clara\20260304_Exp 1.2\segmented\F03\labels_F03_round_004.tif is a low contrast image
# Directory for saving F04 labels created.
# more than 65535 masks in image, masks returned as np.uint32
# c:\Users\Purvis_Jane\.conda\envs\GPU_Segment_4i\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Z:\Clara\20260304_Exp 1.2\segmented\F04\labels_F04_round_000.tif is a low contrast image
# more than 65535 masks in image, masks returned as np.uint32
# c:\Users\Purvis_Jane\.conda\envs\GPU_Segment_4i\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Z:\Clara\20260304_Exp 1.2\segmented\F04\labels_F04_round_002.tif is a low contrast image
# more than 65535 masks in image, masks returned as np.uint32
# c:\Users\Purvis_Jane\.conda\envs\GPU_Segment_4i\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Z:\Clara\20260304_Exp 1.2\segmented\F04\labels_F04_round_003.tif is a low contrast image
# Directory for saving F05 labels created.
# Directory for saving F06 labels created.
# Directory for saving F07 labels created.
# Directory for saving G02 labels created.
# Directory for saving G03 labels created.
# Directory for saving G04 labels created.
# Directory for saving G05 labels created.
# Directory for saving G06 labels created.
# Directory for saving G07 labels created.
