# %% [markdown]
# ## About this notebook

# %% [markdown]
# This notebook prepares 4i data for alignment. It can work for multiple wells from a single experiment as long as they share the 40 antibody set. If it's not the case, the subsets of an experiment should be processed separately.
#
#
# Input:
# - a set of stitched nd2 images with 4i data (- see data structure details in the git readme file)
# - csv file translating optical configurations (OC) into the names of the channels (usually the names of antibodies or target proteins)
#
# Output:
# - a data frame (saved as pkl file) with the info about all the images that will be processed in this experiment
# - a set of single channel tiff files of equal size

# %% [markdown]
# ## Fill in info about the experiment to process

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..', 'src'))
from project_config import load_config

config    = load_config()
base_dir  = config['base_dir']
well_list = config['well_list']

# Sub-folder paths — change only the folder name if yours differs
path_info_file = os.path.join(base_dir, 'info_exp.csv')
path_data      = os.path.join(base_dir, 'data')
path_save_df   = os.path.join(base_dir, 'output_df')
path_save_im   = os.path.join(base_dir, 'output_images')

# %%
# decide which frames will be used for the alignment
# in the provided example all channels with 'DNA' signal will be used

def sel_2_align(myData):
    
    myData['alignIm'] = (myData.signal=='DNA').astype(int)
    
    return myData

# %% [markdown]
# ## Prepare for processing

# %%
import os
import re
import pickle
import pandas as pd
import numpy as np
import nd2
from tifffile import imsave

# %%
# create directory for saving data frames if needed
try:
    os.mkdir(path_save_df)
    print('Directory for saving data frames created.')
except:
    print('Directory not created.')
    
# create directory for saving images if needed    
try:
    os.mkdir(path_save_im)
    print('Directory for saving images created.')
except:
    print('Directory not created.')
# Out:
# Directory not created.
# Directory not created.

# %%
def build_data_frame(path_info_file,path_data,myWell): 
    
    # read in the file with the info about the eperiment
    myDataRounds = pd.read_csv(path_info_file)
    #print(myDataRounds)

    # create a list of subdirectories
    myFiles = os.listdir(path_data)
    #print(myFiles)

    myData=pd.DataFrame()

    k=0
    round_index = 0
    
    for i,myRoundInfo in myDataRounds.iterrows():

        mySubDirName = [x for x in myFiles if (f'Round_{myRoundInfo.myRound}_' in x)]
        #print(myRoundInfo.myRound)
        #print(mySubDirName)
        
        mySubDir = os.path.join(path_data,mySubDirName[0])
        #print(mySubDir)

        myFileName = [x for x in os.listdir(mySubDir) if f'Well{myWell}_Channel' in x][0]
        #print(myFileName)

        # get a handle to the file
        myIm = nd2.ND2File(os.path.join(mySubDir,myFileName))

        # through the channels in the file
        for j in range(myIm.sizes['C']):

            # get the channel name (OC)
            myChannel = myIm.metadata.channels[j].channel.name

            # translate the OC into the signal name
            mySignal = myRoundInfo[myChannel]

            if mySignal == mySignal: # if this channel was admitted (otherwise no entry in the info file)

                myData.loc[k,'dir'] = path_data
                myData.loc[k,'sub_dir'] = mySubDirName
                
                myData.loc[k,'file'] = myFileName
                myData.loc[k,'channel_in_file'] = j
                
                myData.loc[k,'nameRound'] = myRoundInfo.myRound      
                myData.loc[k,'well'] = myWell

                myData.loc[k,'signal'] = myRoundInfo[myChannel]
                myData.loc[k,'width'] = myIm.sizes['X']
                myData.loc[k,'height'] = myIm.sizes['Y']
                
                myData.loc[k,'alignRound'] = round_index

                k = k+1
                
        round_index = round_index + 1 
                
    # calculate min size
    width_min = np.min(myData.width)
    height_min = np.min(myData.height)
    
    myData['width_min'] = width_min
    myData['height_min'] = height_min
    
    return myData

def check_selection_to_align(myData):

    t  = myData.groupby(['nameRound']).sum()
    test1 = list(t.alignIm)==([1]*len(t))
    
    if test1:
        print('Data preparation passed tests.')
    else:
        print('Error - stop and report.')
        
def save_2align_files(myData,save_dir):

    saved = 0
    for ind,my_signal in myData.iterrows():

        if my_signal.alignIm == 1:

            # construct the path
            file_path = os.path.join(my_signal.dir,my_signal.sub_dir,my_signal.file)

            # get a handle to the nd2 file
            myIm = nd2.ND2File(file_path)

            # choose the right frame
            dask_im = myIm.to_dask()
            im = dask_im[my_signal.channel_in_file,:,:]
            
            # trim if needed
            my_well = my_signal.well
            my_round = str(int(my_signal.alignRound)).zfill(3)
            
            if ((my_signal.width_min < my_signal.width) | (my_signal.height_min < my_signal.height)):
                
                im = im[:my_signal.height_min,:my_signal.width_min]
                print(f'Image from well {my_well} from round{my_round} trimmed.')
                
            else:
                
                print(f'Image from well {my_well} from round{my_round} not trimmed.')

            # save the image
            imsave(os.path.join(save_dir,f'im2segment_{my_well}_round_{my_round}.tif'),im.astype('uint16'))
            saved = saved + 1
    
    if saved == 0: 
        print(f'Saved {saved} images.')
    elif saved == 1:
        print(f'Saved {saved} image.')
    else:
        print(f'Saved {saved} images.')

# %% [markdown]
# ## Process selected wells

# %%
for myWell in well_list:
    
    print(f'Processing well {myWell}:')
    
    # create a data frame
    myData = build_data_frame(path_info_file,path_data,myWell)

    # mark images used to calculate the alignment
    myData = sel_2_align(myData)
    
    # test if number of images chosen for the alignment matches the number of rounds
    check_selection_to_align(myData)

    # save data frame
    myData.to_pickle(os.path.join(path_save_df,f'df_{myWell}.pkl'))
    myData.to_csv(os.path.join(path_save_df,f'df_{myWell}.csv'))

    # save channels to align
    try:
        os.mkdir(os.path.join(path_save_im,myWell))
        print(f'Directory {myWell} for images created.')
    except:
        pass
    
    save_2align_files(myData,os.path.join(path_save_im,myWell))
# Out:
# Processing well B02:
# Data preparation passed tests.
# Directory B02 for images created.
# Image from well B02 from round000 not trimmed.
# Saved 1 image.
# Processing well B03:
# Data preparation passed tests.
# Directory B03 for images created.
# Image from well B03 from round000 not trimmed.
# Saved 1 image.
# Processing well B04:
# Data preparation passed tests.
# Directory B04 for images created.
# Image from well B04 from round000 not trimmed.
# Saved 1 image.
# Processing well B05:
# Data preparation passed tests.
# Directory B05 for images created.
# Image from well B05 from round000 not trimmed.
# Saved 1 image.
# Processing well B06:
# Data preparation passed tests.
# Directory B06 for images created.
# Image from well B06 from round000 not trimmed.
# Saved 1 image.
# Processing well B07:
# Data preparation passed tests.
# Directory B07 for images created.
# Image from well B07 from round000 not trimmed.
# Saved 1 image.
# Processing well B08:
# Data preparation passed tests.
# Directory B08 for images created.
# Image from well B08 from round000 not trimmed.
# Saved 1 image.
# Processing well C02:
# Data preparation passed tests.
# Directory C02 for images created.
# Image from well C02 from round000 not trimmed.
# Saved 1 image.
# Processing well C03:
# Data preparation passed tests.
# Directory C03 for images created.
# Image from well C03 from round000 not trimmed.
# Saved 1 image.
# Processing well C04:
# Data preparation passed tests.
# Directory C04 for images created.
# Image from well C04 from round000 not trimmed.
# Saved 1 image.
# Processing well C05:
# Data preparation passed tests.
# Directory C05 for images created.
# Image from well C05 from round000 not trimmed.
# Saved 1 image.
# Processing well C06:
# Data preparation passed tests.
# Directory C06 for images created.
# Image from well C06 from round000 not trimmed.
# Saved 1 image.
# Processing well C07:
# Data preparation passed tests.
# Directory C07 for images created.
# Image from well C07 from round000 not trimmed.
# Saved 1 image.
# Processing well C08:
# Data preparation passed tests.
# Directory C08 for images created.
# Image from well C08 from round000 not trimmed.
# Saved 1 image.
# Processing well D02:
# Data preparation passed tests.
# Directory D02 for images created.
# Image from well D02 from round000 not trimmed.
# Saved 1 image.
# Processing well D03:
# Data preparation passed tests.
# Directory D03 for images created.
# Image from well D03 from round000 not trimmed.
# Saved 1 image.
# Processing well D04:
# Data preparation passed tests.
# Directory D04 for images created.
# Image from well D04 from round000 not trimmed.
# Saved 1 image.
# Processing well D05:
# Data preparation passed tests.
# Directory D05 for images created.
# Image from well D05 from round000 not trimmed.
# Saved 1 image.
# Processing well D06:
# Data preparation passed tests.
# Directory D06 for images created.
# Image from well D06 from round000 not trimmed.
# Saved 1 image.
# Processing well D07:
# Data preparation passed tests.
# Directory D07 for images created.
# Image from well D07 from round000 not trimmed.
# Saved 1 image.
# Processing well D08:
# Data preparation passed tests.
# Directory D08 for images created.
# Image from well D08 from round000 not trimmed.
# Saved 1 image.
# Processing well E02:
# Data preparation passed tests.
# Directory E02 for images created.
# Image from well E02 from round000 not trimmed.
# Saved 1 image.
# Processing well E03:
# Data preparation passed tests.
# Directory E03 for images created.
# Image from well E03 from round000 not trimmed.
# Saved 1 image.
# Processing well E04:
# Data preparation passed tests.
# Directory E04 for images created.
# Image from well E04 from round000 not trimmed.
# Saved 1 image.
# Processing well E05:
# Data preparation passed tests.
# Directory E05 for images created.
# Image from well E05 from round000 not trimmed.
# Saved 1 image.
# Processing well E06:
# Data preparation passed tests.
# Directory E06 for images created.
# Image from well E06 from round000 not trimmed.
# Saved 1 image.
# Processing well E07:
# Data preparation passed tests.
# Directory E07 for images created.
# Image from well E07 from round000 not trimmed.
# Saved 1 image.
# Processing well E08:
# Data preparation passed tests.
# Directory E08 for images created.
# Image from well E08 from round000 not trimmed.
# Saved 1 image.
# Processing well F02:
# Data preparation passed tests.
# Directory F02 for images created.
# Image from well F02 from round000 not trimmed.
# Saved 1 image.
# Processing well F03:
# Data preparation passed tests.
# Directory F03 for images created.
# Image from well F03 from round000 not trimmed.
# Saved 1 image.
# Processing well F04:
# Data preparation passed tests.
# Directory F04 for images created.
# Image from well F04 from round000 not trimmed.
# Saved 1 image.
# Processing well F05:
# Data preparation passed tests.
# Directory F05 for images created.
# Image from well F05 from round000 not trimmed.
# Saved 1 image.
# Processing well F06:
# Data preparation passed tests.
# Directory F06 for images created.
# Image from well F06 from round000 not trimmed.
# Saved 1 image.
# Processing well F07:
# Data preparation passed tests.
# Directory F07 for images created.
# Image from well F07 from round000 not trimmed.
# Saved 1 image.
# Processing well F08:
# Data preparation passed tests.
# Directory F08 for images created.
# Image from well F08 from round000 not trimmed.
# Saved 1 image.
# Processing well G02:
# Data preparation passed tests.
# Directory G02 for images created.
# Image from well G02 from round000 not trimmed.
# Saved 1 image.
# Processing well G03:
# Data preparation passed tests.
# Directory G03 for images created.
# Image from well G03 from round000 not trimmed.
# Saved 1 image.
# Processing well G04:
# Data preparation passed tests.
# Directory G04 for images created.
# Image from well G04 from round000 not trimmed.
# Saved 1 image.
# Processing well G05:
# Data preparation passed tests.
# Directory G05 for images created.
# Image from well G05 from round000 not trimmed.
# Saved 1 image.
# Processing well G06:
# Data preparation passed tests.
# Directory G06 for images created.
# Image from well G06 from round000 not trimmed.
# Saved 1 image.
# Processing well G07:
# Data preparation passed tests.
# Directory G07 for images created.
# Image from well G07 from round000 not trimmed.
# Saved 1 image.
# Processing well G08:
# Data preparation passed tests.
# Directory G08 for images created.
# Image from well G08 from round000 not trimmed.
# Saved 1 image.
