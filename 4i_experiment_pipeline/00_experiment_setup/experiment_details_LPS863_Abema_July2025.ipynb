# %% [markdown]
# # Experiment Setup: LPS863 Abemaciclib July 2025
#
# Each experiment gets its own copy of this notebook (named ).
# Running and saving this notebook sets it as the **active experiment** for all
# downstream notebooks (4i_pipeline, analysis_tools).
#
# 1. **Cell below** — set the  (short slug, no spaces)
# 2. **Plate selector** — click wells, click **Generate Code**, copy
# 3. **Well list cell** — paste your well_list
# 4. **Config form** — fill experiment details and per-well metadata, click **Save Config**
# 5. **Summary** — run the summary cell to see the plate visual (persists on reopen)
# 6. **Image viewer** — click any well to open its 4i images inline

# %%
# Unique short identifier for this experiment (used as config file name).
# Copy this notebook and rename it + change this key for each new experiment.
experiment_key = "LPS863_Abema_July2025"

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), "..", "src"))

from well_plate_selector import show_well_plate_selector
from project_config import show_save_form

# %%
# Click wells on the plate, then click Generate Code.
# Copy the well_list = [...] line into the cell below.

show_well_plate_selector()

# %%
# Paste your well_list line from Generate Code above
well_list = ["D02","D03","D04","D05","D06","D07","D08","E02","E03","E04","E05","E06","E07","E08"]

# %%
# Fill in experiment details and per-well metadata, then click Save Config.
# Saves to experiment_configs/{experiment_key}.json AND to project_config.json (active).
show_save_form(well_list, experiment_key=experiment_key)

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..', 'src'))
from project_summary import show_interactive_summary

# Run this cell after clicking Save Config above.
# Shows the experiment summary plate with clickable wells.
# Click any blue well to open its 4i images below the plate.
show_interactive_summary()
