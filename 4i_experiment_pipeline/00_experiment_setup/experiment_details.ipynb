# %% [markdown]
# # Project Configuration
#
# Run this notebook **once at the start of each experiment**.
#
# 1. **Cell 2** — select wells on the 96-well plate, click **Generate Code**, copy the  line
# 2. **Cell 3** — paste that line here and run the cell
# 3. **Cell 4** — fill in experiment details and per-well metadata, click **Save Config**
#
# All other notebooks in this project will load the saved config automatically.

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), "..", "src"))
from project_summary import show_summary

# Run this cell after saving config, then save the notebook (Ctrl+S).
# The well plate visual will persist and appear every time you reopen the notebook.
show_summary()
# Out:
# <style>
# .wp-tt {
#     display: none;
#     position: absolute;
#     bottom: 115%;
#     left: 50%;
#     transform: translateX(-50%);
#     background: #0a1628;
#     color: #a8d8f0;
#     padding: 5px 9px;
#     border-radius: 6px;
#     font-size: 10px;
#     white-space: nowrap;
#     z-index: 99;
#     border: 1px solid #2a5a74;
#     line-height: 1.6;
#     pointer-events: none;
# }
# .wp-sw:hover .wp-tt { display: block; }
# </style>
# <div style="overflow-x:auto;">
# <div style="background:#111827;padding:20px 24px 24px;border-radius:12px;
#             display:inline-block;min-width:max-content;">
#
#     <div style="font-size:17px;font-weight:bold;color:#cdd6f4;margin-bottom:10px;">
#         Liposarcoma 863 Abemaciclib Treatment July 2025
#     </div>
#     <table style="border-collapse:collapse;font-size:12px;margin-bottom:16px;">
# ...

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), "..", "src"))

from well_plate_selector import show_well_plate_selector
from project_config import show_save_form

# %%
# Step 1: click your wells, then click Generate Code
# Copy the well_list = [...] line into the cell below

show_well_plate_selector()
# Out:
# <div id="plate_p85121" style="background:#111827;padding:18px 22px 20px;border-radius:14px;display:inline-block;"><div style="font-size:15px;font-weight:bold;color:#cdd6f4;margin-bottom:10px;">96-Well Plate Selector</div><div style="display:flex;margin-left:32px;margin-bottom:4px;"><div style="width:50px;flex:0 0 50px;text-align:center;color:#6a9ab0;font-size:11px;font-weight:bold;box-sizing:border-box;">1</div><div style="width:50px;flex:0 0 50px;text-align:center;color:#6a9ab0;font-size:11px;font-weight:bold;box-sizing:border-box;">2</div><div style="width:50px;flex:0 0 50px;text-align:center;color:#6a9ab0;font-size:11px;font-weight:bold;box-sizing:border-box;">3</div><div style="width:50px;flex:0 0 50px;text-align:center;color:#6a9ab0;font-size:11px;font-weight:bold;box-sizing:border-box;">4</div><div style="width:50px;flex:0 0 50px;text-align:center;color:#6a9ab0;font-size:11px;font-weight:bold;box-sizing:border-box;">5</div><div style="width:50px;flex:0 0 50px;text-align:center;
# ...

# %%
# Step 2: paste your well_list line from the Generate Code output above
well_list = ["D02","D03","D04","D05","D06","D07","D08","E02","E03","E04","E05","E06","E07","E08"]

# %%
# Step 3: fill in the form and click Save Config
show_save_form(well_list)
